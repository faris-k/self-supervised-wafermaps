# %%
import os
import warnings

import hdbscan
import numpy as np
import pandas as pd
import plotly.express as px
import seaborn as sns
import umap
from ax.plot.pareto_frontier import plot_pareto_frontier
from ax.plot.pareto_utils import compute_posterior_pareto_frontier
from ax.service.ax_client import AxClient
from ax.service.managed_loop import optimize
from ax.service.utils.instantiation import ObjectiveProperties
from sklearn.metrics import (
    calinski_harabasz_score,
    davies_bouldin_score,
    silhouette_score,
)

from ssl_wafermap.utilities.plotting import create_subplots, mpn65_palette

warnings.filterwarnings("ignore")

# %%
df = pd.read_pickle("../data/interim/model_preds/SwaV_preds_full.pkl.xz")
cols = df.columns.difference(["failureType", "failureCode", "waferMap"])
data = df[cols].values

# %%
reducer = umap.UMAP(
    random_state=0,
    n_neighbors=30,
    min_dist=0,
    n_components=50,
    densmap=True,
    dens_lambda=0.1,
)
reduced_data = reducer.fit_transform(data)

# %%
def hdbscan_evaluation_function(parameterization):
    # Perform HDBSCAN clustering on the data with given parameters
    clusterer = hdbscan.HDBSCAN(
        min_samples=parameterization.get("min_samples"),
        min_cluster_size=parameterization.get("min_cluster_size"),
        cluster_selection_epsilon=parameterization.get("cluster_selection_epsilon"),
        metric=parameterization.get("metric"),
    )
    # clusterer.fit(data)
    clusterer.fit(reduced_data)

    # Calculate the number of clusters and points labeled as noise to constrain the optimization
    labels = clusterer.labels_
    n_clusters = labels.max() + 1
    n_noise = (labels == -1).sum()

    # Compute the silhouette score, Calinski-Harabasz score, and Davies-Bouldin score
    # These should be on the subset of the data NOT labeled as noise (i.e. labels != -1)
    subset_data, subset_labels = reduced_data[labels != -1], labels[labels != -1]
    silhouette = silhouette_score(subset_data, subset_labels)
    calinski_harabasz = calinski_harabasz_score(subset_data, subset_labels)
    davies_bouldin = davies_bouldin_score(subset_data, subset_labels)

    # Return the evaluation metrics and outcome constraints
    # These are tuples of the metrics with the SEM
    return {
        "n_noise": (n_noise, 0),
        "n_clusters": (n_clusters, 0),
        "silhouette": (silhouette, 0),
        "calinski_harabasz": (calinski_harabasz, 0),
        "davies_bouldin": (davies_bouldin, 0),
    }


# Create a search space for the hyperparameters
parameters = [
    {"name": "min_samples", "type": "range", "bounds": [1, 60], "value_type": "int"},
    {
        "name": "min_cluster_size",
        "type": "range",
        "bounds": [10, 100],
        "value_type": "int",
    },
    {
        "name": "cluster_selection_epsilon",
        "type": "range",
        "bounds": [0.1, 1.5],
        "value_type": "float",
    },
    {
        "name": "metric",
        "type": "choice",
        "values": ["euclidean", "manhattan", "canberra", "braycurtis"],
        "value_type": "str",
        "is_ordered": False,
    },
]


# Initialize the optimization client
ax_client = AxClient(random_seed=0)
ax_client.create_experiment(
    parameters=parameters,
    # Optimize cluster evaluation metrics while minimizing the number of noise points
    objectives={
        "silhouette": ObjectiveProperties(minimize=False),
        "calinski_harabasz": ObjectiveProperties(minimize=False),
        "davies_bouldin": ObjectiveProperties(minimize=True),
        "n_noise": ObjectiveProperties(minimize=True),
    },
    # We will constrain the number of possible clusters
    outcome_constraints=["n_clusters <= 50", "n_clusters >= 25"],
    overwrite_existing_experiment=True,
)

# Run 30 trials
for i in range(30):
    parameterization, trial_index = ax_client.get_next_trial()
    ax_client.complete_trial(
        trial_index=trial_index,
        raw_data=hdbscan_evaluation_function(parameterization),
    )
# Out:
# [INFO 05-22 10:58:33] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# [WARNING 05-22 10:58:33] ax.service.ax_client: Random seed set to 0. Note that this setting only affects the Sobol quasi-random generator and BoTorch-powered Bayesian optimization models. For the latter models, setting random seed to the same number for two optimizations will make the generated trials similar, but not exactly the same, and over time the trials will diverge more.
# [INFO 05-22 10:58:33] ax.service.utils.instantiation: Due to non-specification, we will use the heuristic for selecting objective thresholds.
# [INFO 05-22 10:58:33] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='min_samples', parameter_type=INT, range=[1, 60]), RangeParameter(name='min_cluster_size', parameter_type=INT, range=[10, 100]), RangeParameter(name='cluster_selection_epsilon', parameter_type=FLOAT, range=[0.1, 1.5]), ChoiceParameter(name='metric', parameter_type=STRING, values=['euclidean', 'manhattan', 'canberra', 'braycurtis'], is_ordered=False, sort_values=False)], parameter_constraints=[]).
# [INFO 05-22 10:58:33] ax.modelbridge.dispatch_utils: Using Bayesian optimization with a categorical kernel for improved performance with a large number of unordered categorical parameters.
# [INFO 05-22 10:58:33] ax.modelbridge.dispatch_utils: Calculating the number of remaining initialization trials based on num_initialization_trials=None max_initialization_trials=None num_tunable_parameters=4 num_trials=None use_batch_trials=False
# [INFO 05-22 10:58:33] ax.modelbridge.dispatch_utils: calculated num_initialization_trials=8
# [INFO 05-22 10:58:33] ax.modelbridge.dispatch_utils: num_completed_initialization_trials=0 num_remaining_initialization_trials=8
# [INFO 05-22 10:58:33] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+BO_MIXED', steps=[Sobol for 8 trials, BO_MIXED for subsequent trials]). Iterations after 8 will take longer to generate due to model-fitting.
# [INFO 05-22 10:58:33] ax.service.ax_client: Generated new trial 0 with parameters {'min_samples': 29, 'min_cluster_size': 63, 'cluster_selection_epsilon': 0.792271, 'metric': 'canberra'}.
# [INFO 05-22 10:59:25] ax.service.ax_client: Completed trial 0 with data: {'n_noise': (261, 0), 'n_clusters': (14, 0), 'silhouette': (0.45257226, 0), 'calinski_harabasz': (34470.637214, 0), 'davies_bouldin': (0.584565, 0)}.
# [INFO 05-22 10:59:26] ax.service.ax_client: Generated new trial 1 with parameters {'min_samples': 48, 'min_cluster_size': 39, 'cluster_selection_epsilon': 1.11402, 'metric': 'euclidean'}.
# [INFO 05-22 10:59:51] ax.service.ax_client: Completed trial 1 with data: {'n_noise': (66, 0), 'n_clusters': (12, 0), 'silhouette': (0.6170578, 0), 'calinski_harabasz': (34560.213594, 0), 'davies_bouldin': (0.414088, 0)}.
# [INFO 05-22 10:59:51] ax.service.ax_client: Generated new trial 2 with parameters {'min_samples': 39, 'min_cluster_size': 98, 'cluster_selection_epsilon': 0.10086, 'metric': 'euclidean'}.
# [INFO 05-22 11:00:10] ax.service.ax_client: Completed trial 2 with data: {'n_noise': (5570, 0), 'n_clusters': (26, 0), 'silhouette': (0.68492466, 0), 'calinski_harabasz': (111614.183012, 0), 'davies_bouldin': (0.523689, 0)}.
# [INFO 05-22 11:00:10] ax.service.ax_client: Generated new trial 3 with parameters {'min_samples': 6, 'min_cluster_size': 32, 'cluster_selection_epsilon': 1.192848, 'metric': 'braycurtis'}.
# [INFO 05-22 11:00:52] ax.service.ax_client: Completed trial 3 with data: {'n_noise': (16, 0), 'n_clusters': (2, 0), 'silhouette': (0.37212783, 0), 'calinski_harabasz': (8331.701498, 0), 'davies_bouldin': (0.693916, 0)}.
# [INFO 05-22 11:00:52] ax.service.ax_client: Generated new trial 4 with parameters {'min_samples': 11, 'min_cluster_size': 83, 'cluster_selection_epsilon': 0.885242, 'metric': 'braycurtis'}.
# [INFO 05-22 11:01:30] ax.service.ax_client: Completed trial 4 with data: {'n_noise': (16, 0), 'n_clusters': (2, 0), 'silhouette': (0.37212783, 0), 'calinski_harabasz': (8331.701498, 0), 'davies_bouldin': (0.693916, 0)}.
# [INFO 05-22 11:01:31] ax.service.ax_client: Generated new trial 5 with parameters {'min_samples': 37, 'min_cluster_size': 13, 'cluster_selection_epsilon': 0.496054, 'metric': 'euclidean'}.
# [INFO 05-22 11:01:53] ax.service.ax_client: Completed trial 5 with data: {'n_noise': (1582, 0), 'n_clusters': (19, 0), 'silhouette': (0.5838227, 0), 'calinski_harabasz': (51367.279919, 0), 'davies_bouldin': (0.402212, 0)}.
# [INFO 05-22 11:01:53] ax.service.ax_client: Generated new trial 6 with parameters {'min_samples': 57, 'min_cluster_size': 68, 'cluster_selection_epsilon': 1.418826, 'metric': 'braycurtis'}.
# [INFO 05-22 11:02:27] ax.service.ax_client: Completed trial 6 with data: {'n_noise': (16, 0), 'n_clusters': (2, 0), 'silhouette': (0.37213185, 0), 'calinski_harabasz': (8331.865409, 0), 'davies_bouldin': (0.693911, 0)}.
# [INFO 05-22 11:02:27] ax.service.ax_client: Generated new trial 7 with parameters {'min_samples': 16, 'min_cluster_size': 46, 'cluster_selection_epsilon': 0.399877, 'metric': 'manhattan'}.
# [INFO 05-22 11:02:49] ax.service.ax_client: Completed trial 7 with data: {'n_noise': (4123, 0), 'n_clusters': (58, 0), 'silhouette': (0.6939544, 0), 'calinski_harabasz': (53025.825137, 0), 'davies_bouldin': (0.585007, 0)}.
# [WARNING 05-22 11:02:49] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:03:02] ax.service.ax_client: Generated new trial 8 with parameters {'min_samples': 60, 'min_cluster_size': 90, 'cluster_selection_epsilon': 0.1, 'metric': 'euclidean'}.
# [INFO 05-22 11:03:24] ax.service.ax_client: Completed trial 8 with data: {'n_noise': (3257, 0), 'n_clusters': (22, 0), 'silhouette': (0.61983556, 0), 'calinski_harabasz': (102606.601643, 0), 'davies_bouldin': (0.472536, 0)}.
# [WARNING 05-22 11:03:24] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:03:51] ax.service.ax_client: Generated new trial 9 with parameters {'min_samples': 43, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.1, 'metric': 'euclidean'}.
# [INFO 05-22 11:04:12] ax.service.ax_client: Completed trial 9 with data: {'n_noise': (6108, 0), 'n_clusters': (29, 0), 'silhouette': (0.6902916, 0), 'calinski_harabasz': (100973.274769, 0), 'davies_bouldin': (0.499381, 0)}.
# [WARNING 05-22 11:04:12] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:04:38] ax.service.ax_client: Generated new trial 10 with parameters {'min_samples': 43, 'min_cluster_size': 96, 'cluster_selection_epsilon': 0.1, 'metric': 'euclidean'}.
# [INFO 05-22 11:04:56] ax.service.ax_client: Completed trial 10 with data: {'n_noise': (6108, 0), 'n_clusters': (29, 0), 'silhouette': (0.6902916, 0), 'calinski_harabasz': (100973.274769, 0), 'davies_bouldin': (0.499381, 0)}.
# [WARNING 05-22 11:04:56] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:05:09] ax.service.ax_client: Generated new trial 11 with parameters {'min_samples': 44, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.112086, 'metric': 'euclidean'}.
# [INFO 05-22 11:05:27] ax.service.ax_client: Completed trial 11 with data: {'n_noise': (5909, 0), 'n_clusters': (28, 0), 'silhouette': (0.6949524, 0), 'calinski_harabasz': (107791.153745, 0), 'davies_bouldin': (0.546312, 0)}.
# [WARNING 05-22 11:05:27] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:05:57] ax.service.ax_client: Generated new trial 12 with parameters {'min_samples': 45, 'min_cluster_size': 14, 'cluster_selection_epsilon': 0.122843, 'metric': 'euclidean'}.
# [INFO 05-22 11:06:16] ax.service.ax_client: Completed trial 12 with data: {'n_noise': (5204, 0), 'n_clusters': (55, 0), 'silhouette': (0.6268474, 0), 'calinski_harabasz': (54949.073181, 0), 'davies_bouldin': (0.473347, 0)}.
# [WARNING 05-22 11:06:16] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:06:42] ax.service.ax_client: Generated new trial 13 with parameters {'min_samples': 44, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.140984, 'metric': 'euclidean'}.
# [INFO 05-22 11:07:01] ax.service.ax_client: Completed trial 13 with data: {'n_noise': (5909, 0), 'n_clusters': (28, 0), 'silhouette': (0.6949524, 0), 'calinski_harabasz': (107791.153745, 0), 'davies_bouldin': (0.546312, 0)}.
# [WARNING 05-22 11:07:01] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:07:33] ax.service.ax_client: Generated new trial 14 with parameters {'min_samples': 46, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.325034, 'metric': 'euclidean'}.
# [INFO 05-22 11:07:54] ax.service.ax_client: Completed trial 14 with data: {'n_noise': (3555, 0), 'n_clusters': (18, 0), 'silhouette': (0.6503648, 0), 'calinski_harabasz': (120826.792444, 0), 'davies_bouldin': (0.478496, 0)}.
# [WARNING 05-22 11:07:54] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:09:07] ax.service.ax_client: Generated new trial 15 with parameters {'min_samples': 5, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.464235, 'metric': 'euclidean'}.
# [INFO 05-22 11:09:32] ax.service.ax_client: Completed trial 15 with data: {'n_noise': (476, 0), 'n_clusters': (12, 0), 'silhouette': (0.4852141, 0), 'calinski_harabasz': (36699.313705, 0), 'davies_bouldin': (0.594846, 0)}.
# [WARNING 05-22 11:09:32] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:10:34] ax.service.ax_client: Generated new trial 16 with parameters {'min_samples': 47, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.152732, 'metric': 'euclidean'}.
# [INFO 05-22 11:10:56] ax.service.ax_client: Completed trial 16 with data: {'n_noise': (2739, 0), 'n_clusters': (22, 0), 'silhouette': (0.6038652, 0), 'calinski_harabasz': (97853.934896, 0), 'davies_bouldin': (0.494547, 0)}.
# [WARNING 05-22 11:10:56] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:11:47] ax.service.ax_client: Generated new trial 17 with parameters {'min_samples': 46, 'min_cluster_size': 72, 'cluster_selection_epsilon': 0.400921, 'metric': 'euclidean'}.
# [INFO 05-22 11:12:10] ax.service.ax_client: Completed trial 17 with data: {'n_noise': (2038, 0), 'n_clusters': (15, 0), 'silhouette': (0.62221366, 0), 'calinski_harabasz': (79264.760163, 0), 'davies_bouldin': (0.421592, 0)}.
# [WARNING 05-22 11:12:10] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:13:14] ax.service.ax_client: Generated new trial 18 with parameters {'min_samples': 46, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.394319, 'metric': 'manhattan'}.
# [INFO 05-22 11:13:33] ax.service.ax_client: Completed trial 18 with data: {'n_noise': (5784, 0), 'n_clusters': (26, 0), 'silhouette': (0.7607085, 0), 'calinski_harabasz': (113414.788016, 0), 'davies_bouldin': (0.454345, 0)}.
# [WARNING 05-22 11:13:33] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:14:04] ax.service.ax_client: Generated new trial 19 with parameters {'min_samples': 47, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.376523, 'metric': 'manhattan'}.
# [INFO 05-22 11:14:24] ax.service.ax_client: Completed trial 19 with data: {'n_noise': (6301, 0), 'n_clusters': (28, 0), 'silhouette': (0.7600546, 0), 'calinski_harabasz': (103589.206674, 0), 'davies_bouldin': (0.451481, 0)}.
# [WARNING 05-22 11:14:24] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:15:28] ax.service.ax_client: Generated new trial 20 with parameters {'min_samples': 55, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.413994, 'metric': 'manhattan'}.
# [INFO 05-22 11:15:47] ax.service.ax_client: Completed trial 20 with data: {'n_noise': (6141, 0), 'n_clusters': (25, 0), 'silhouette': (0.75890356, 0), 'calinski_harabasz': (112798.937699, 0), 'davies_bouldin': (0.432792, 0)}.
# [WARNING 05-22 11:15:47] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:17:00] ax.service.ax_client: Generated new trial 21 with parameters {'min_samples': 60, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.368486, 'metric': 'manhattan'}.
# [INFO 05-22 11:17:23] ax.service.ax_client: Completed trial 21 with data: {'n_noise': (3083, 0), 'n_clusters': (21, 0), 'silhouette': (0.66983, 0), 'calinski_harabasz': (107929.161186, 0), 'davies_bouldin': (0.443034, 0)}.
# [WARNING 05-22 11:17:23] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:18:37] ax.service.ax_client: Generated new trial 22 with parameters {'min_samples': 51, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.221726, 'metric': 'manhattan'}.
# [INFO 05-22 11:18:56] ax.service.ax_client: Completed trial 22 with data: {'n_noise': (6082, 0), 'n_clusters': (26, 0), 'silhouette': (0.7651048, 0), 'calinski_harabasz': (112728.843202, 0), 'davies_bouldin': (0.427102, 0)}.
# [WARNING 05-22 11:18:56] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:20:14] ax.service.ax_client: Generated new trial 23 with parameters {'min_samples': 49, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.17198, 'metric': 'manhattan'}.
# [INFO 05-22 11:20:32] ax.service.ax_client: Completed trial 23 with data: {'n_noise': (6311, 0), 'n_clusters': (28, 0), 'silhouette': (0.75980854, 0), 'calinski_harabasz': (103663.768149, 0), 'davies_bouldin': (0.452676, 0)}.
# [WARNING 05-22 11:20:32] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:21:43] ax.service.ax_client: Generated new trial 24 with parameters {'min_samples': 45, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.433459, 'metric': 'manhattan'}.
# [INFO 05-22 11:22:02] ax.service.ax_client: Completed trial 24 with data: {'n_noise': (5809, 0), 'n_clusters': (26, 0), 'silhouette': (0.75201935, 0), 'calinski_harabasz': (109034.151265, 0), 'davies_bouldin': (0.449531, 0)}.
# [WARNING 05-22 11:22:02] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:23:26] ax.service.ax_client: Generated new trial 25 with parameters {'min_samples': 53, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.299149, 'metric': 'manhattan'}.
# [INFO 05-22 11:23:45] ax.service.ax_client: Completed trial 25 with data: {'n_noise': (5817, 0), 'n_clusters': (25, 0), 'silhouette': (0.75490403, 0), 'calinski_harabasz': (113780.108137, 0), 'davies_bouldin': (0.455306, 0)}.
# [WARNING 05-22 11:23:45] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:25:02] ax.service.ax_client: Generated new trial 26 with parameters {'min_samples': 51, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.383701, 'metric': 'manhattan'}.
# [INFO 05-22 11:25:21] ax.service.ax_client: Completed trial 26 with data: {'n_noise': (6082, 0), 'n_clusters': (26, 0), 'silhouette': (0.7651048, 0), 'calinski_harabasz': (112728.843202, 0), 'davies_bouldin': (0.427102, 0)}.
# [WARNING 05-22 11:25:21] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:26:58] ax.service.ax_client: Generated new trial 27 with parameters {'min_samples': 54, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.226496, 'metric': 'manhattan'}.
# [INFO 05-22 11:27:18] ax.service.ax_client: Completed trial 27 with data: {'n_noise': (6171, 0), 'n_clusters': (27, 0), 'silhouette': (0.70687294, 0), 'calinski_harabasz': (110536.23019, 0), 'davies_bouldin': (0.448597, 0)}.
# [WARNING 05-22 11:27:18] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:28:28] ax.service.ax_client: Generated new trial 28 with parameters {'min_samples': 46, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.431833, 'metric': 'manhattan'}.
# [INFO 05-22 11:28:48] ax.service.ax_client: Completed trial 28 with data: {'n_noise': (5784, 0), 'n_clusters': (26, 0), 'silhouette': (0.7607085, 0), 'calinski_harabasz': (113414.788016, 0), 'davies_bouldin': (0.454345, 0)}.
# [WARNING 05-22 11:28:49] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:30:11] ax.service.ax_client: Generated new trial 29 with parameters {'min_samples': 41, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.398654, 'metric': 'manhattan'}.
# [INFO 05-22 11:30:31] ax.service.ax_client: Completed trial 29 with data: {'n_noise': (5371, 0), 'n_clusters': (25, 0), 'silhouette': (0.7395297, 0), 'calinski_harabasz': (113639.788305, 0), 'davies_bouldin': (0.510373, 0)}.

# %%
# Retrieve the best parameters
best_param_dict = ax_client.get_pareto_optimal_parameters()

# Display the best parameters and their evaluation metrics
summary_table = []
for exp_idx, summary in best_param_dict.items():
    params, (eval_metrics, sems) = summary
    row = {"Experiment": exp_idx, **params, **eval_metrics}
    summary_table.append(row)

summary_table = pd.DataFrame(summary_table)
int_cols = ["n_clusters", "n_noise"]
summary_table[int_cols] = summary_table[int_cols].astype(int)

param_cols = ["min_samples", "min_cluster_size", "cluster_selection_epsilon", "metric"]
obj_cols = [
    "n_clusters",
    "n_noise",
    "silhouette",
    "calinski_harabasz",
    "davies_bouldin",
]

param_df = summary_table[param_cols]
obj_df = summary_table[obj_cols]

# Concatenate the grouped columns
df_summary = pd.concat(
    [param_df, obj_df], axis=1, keys=["Hyperparameters", "Objectives"]
)
df_summary.index = summary_table["Experiment"]
df_summary
# Out:
# [WARNING 05-22 11:30:31] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-22 11:31:01] ax.service.utils.best_point: Using inferred objective thresholds: [ObjectiveThreshold(calinski_harabasz >= 106532.31080560196), ObjectiveThreshold(davies_bouldin <= 0.5052049976231597), ObjectiveThreshold(n_noise <= 6668.193151355564), ObjectiveThreshold(silhouette >= 0.6530150630123105)], as objective thresholds were not specified as part of the optimization configuration on the experiment.
#            Hyperparameters
#                min_samples min_cluster_size cluster_selection_epsilon
# Experiment
# 16                      47              100                  0.152732  \
# 18                      46              100                  0.394319
# 19                      47              100                  0.376523
# 22                      51              100                  0.221726
# 23                      49              100                  0.171980
# 25                      53              100                  0.299149
# 26                      51              100                  0.383701
# 28                      46              100                  0.431833
# 29                      41              100                  0.398654
#
#                       Objectives
#                metric n_clusters n_noise silhouette calinski_harabasz
# Experiment
# 16          euclidean         25    2739   0.662906     107090.742123  \
# 18          manhattan         26    5784   0.757863     112163.938301
# 19          manhattan         26    6300   0.757490     112675.055295
# 22          manhattan         26    6082   0.752193     109883.162297
# 23          manhattan         28    6310   0.761815     107770.336260
# 25          manhattan         25    5817   0.741067     111933.460386
# 26          manhattan         25    6082   0.746734     112528.755698
# 28          manhattan         25    5784   0.755467     110957.850974
# 29          manhattan         26    5370   0.758244     109881.990856
#
#
#            davies_bouldin
# Experiment
# 16               0.498947
# 18               0.455913
# 19               0.450873
# 22               0.445613
# 23               0.455709
# 25               0.438201
# 26               0.436363
# 28               0.454833
# 29               0.488614

# %%
# Create a 2D UMAP embedding of the data
reducer_2d = umap.UMAP(random_state=0)
embedding_2d = reducer_2d.fit_transform(data)

# %%
best_idx = 16
best_params = best_param_dict[best_idx][0]

# Perform HDBSCAN clustering on the data with the best parameters
clusterer = hdbscan.HDBSCAN(**best_params)
clusterer.fit(reduced_data)

# %%
emb_df = pd.DataFrame(embedding_2d, columns=["x", "y"])
emb_df["failureType"] = df["failureType"].values
emb_df["waferMap"] = df["waferMap"].values
emb_df["cluster"] = pd.Series(clusterer.labels_).astype("category").values
emb_df.sort_values("cluster", inplace=True)

# %%
fig = px.scatter(
    emb_df,
    x="x",
    y="y",
    color="cluster",
    # color_discrete_sequence=px.colors.qualitative.Light24,
    color_discrete_sequence=mpn65_palette(),
    width=800,
    height=600,
    template="simple_white",
    color_discrete_map={-1: "lightgray"},
)
# fig.update_traces(
#     marker=dict(
#         line=dict(
#             width=emb_df["cluster"].map(lambda x: 0.5 if x < 0 else 0).values,
#             color="white",
#         )
#     )
# )
fig.show()

# %%
import base64
from io import BytesIO

import matplotlib.pyplot as plt
from bokeh.models import CategoricalColorMapper, ColumnDataSource, HoverTool
from bokeh.palettes import Spectral10, Category20_20
from bokeh.plotting import figure, output_notebook, show
from PIL import Image
from sklearn.datasets import load_digits

output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1001">Loading BokehJS ...</span>
#     </div>

# %%
def embeddable_image(data):
    image = Image.fromarray(data, mode="L").resize((100, 100), resample=Image.Resampling.NEAREST)
    buffer = BytesIO()
    image.save(buffer, format="png")
    for_encoding = buffer.getvalue()
    return "data:image/png;base64," + base64.b64encode(for_encoding).decode()


emb_df["image"] = list(map(embeddable_image, emb_df.waferMap))
# list(map(embeddable_image, emb_df.waferMap))

# %%
plot_figure = figure(
    title="Interactive UMAP Plot of SwAV Features with HDBSCAN Cluster Labels",
    width=1000,
    height=600,
)
plot_figure.add_tools(
    HoverTool(
        tooltips="""
<div>
    <div>
        <img src='@image' style='float: left; margin: 5px 5px 5px 5px'/>
    </div>
    <div>
        <span style='font-size: 16px; color: #224499'>Cluster:</span>
        <span style='font-size: 18px'>@cluster</span>
    </div>
</div>
"""
    )
)

# We have to plot each cluster group separately, because the hover tool doesn't work with a legend otherwise
colors = ["#d4d4d4"] + mpn65_palette()
for (digit, group), name, color in zip(
    emb_df.groupby("cluster"), emb_df.cluster.unique(), colors
):
    plot_figure.circle(
        "x",
        "y",
        source=group,
        color=color,
        line_alpha=0.8,
        fill_alpha=0.7,
        # radius=.1,
        size=5,
        radius_dimension="x",
        legend_label=f"{name}",
    )

# Move the legend to the right, outside the plot
plot_figure.add_layout(plot_figure.legend[0], "right")

# Title the legend and make it interactive
plot_figure.legend.title = "HDBSCAN Cluster"
# plot_figure.legend.location = "top_left"
plot_figure.legend.click_policy = "hide"

show(plot_figure)
