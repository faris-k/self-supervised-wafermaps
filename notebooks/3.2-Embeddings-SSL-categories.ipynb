# %%
import os
import warnings

import hdbscan
import numpy as np
import pandas as pd
import plotly.express as px
import seaborn as sns
import umap
from ax.plot.pareto_frontier import plot_pareto_frontier
from ax.plot.pareto_utils import compute_posterior_pareto_frontier
from ax.service.ax_client import AxClient
from ax.service.managed_loop import optimize
from ax.service.utils.instantiation import ObjectiveProperties
from sklearn.metrics import (
    calinski_harabasz_score,
    davies_bouldin_score,
    silhouette_score,
)

from ssl_wafermap.utilities.plotting import create_subplots, mpn65_palette

warnings.filterwarnings("ignore")

# %%
df = pd.read_pickle("../data/interim/model_preds/SwaV_preds_full.pkl.xz")
cols = df.columns.difference(["failureType", "failureCode", "waferMap"])
data = df[cols].values

# %%
reducer = umap.UMAP(
    random_state=0,
    n_neighbors=30,
    min_dist=0,
    n_components=50,
    densmap=True,
    dens_lambda=0.1,
)
reduced_data = reducer.fit_transform(data)

# %%
def hdbscan_evaluation_function(parameterization):
    # Perform HDBSCAN clustering on the data with given parameters
    clusterer = hdbscan.HDBSCAN(
        min_samples=parameterization.get("min_samples"),
        min_cluster_size=parameterization.get("min_cluster_size"),
        cluster_selection_epsilon=parameterization.get("cluster_selection_epsilon"),
        metric=parameterization.get("metric"),
    )
    # clusterer.fit(data)
    clusterer.fit(reduced_data)

    # Calculate the number of clusters and points labeled as noise to constrain the optimization
    labels = clusterer.labels_
    n_clusters = labels.max() + 1
    n_noise = (labels == -1).sum()

    # Compute the silhouette score, Calinski-Harabasz score, and Davies-Bouldin score
    # These should be on the subset of the data NOT labeled as noise (i.e. labels != -1)
    subset_data, subset_labels = reduced_data[labels != -1], labels[labels != -1]
    silhouette = silhouette_score(subset_data, subset_labels)
    calinski_harabasz = calinski_harabasz_score(subset_data, subset_labels)
    davies_bouldin = davies_bouldin_score(subset_data, subset_labels)

    # Return the evaluation metrics and outcome constraints
    # These are tuples of the metrics with the SEM
    return {
        "n_noise": (n_noise, 0),
        "n_clusters": (n_clusters, 0),
        "silhouette": (silhouette, 0),
        "calinski_harabasz": (calinski_harabasz, 0),
        "davies_bouldin": (davies_bouldin, 0),
    }


# Create a search space for the hyperparameters
parameters = [
    {"name": "min_samples", "type": "range", "bounds": [1, 60], "value_type": "int"},
    {
        "name": "min_cluster_size",
        "type": "range",
        "bounds": [10, 100],
        "value_type": "int",
    },
    {
        "name": "cluster_selection_epsilon",
        "type": "range",
        "bounds": [0.1, 1.5],
        "value_type": "float",
    },
    {
        "name": "metric",
        "type": "choice",
        "values": ["euclidean", "manhattan", "canberra", "braycurtis"],
        "value_type": "str",
        "is_ordered": False,
    },
]


# Initialize the optimization client
ax_client = AxClient(random_seed=0)
ax_client.create_experiment(
    parameters=parameters,
    # Optimize cluster evaluation metrics while minimizing the number of noise points
    objectives={
        "silhouette": ObjectiveProperties(minimize=False),
        "calinski_harabasz": ObjectiveProperties(minimize=False),
        "davies_bouldin": ObjectiveProperties(minimize=True),
        "n_noise": ObjectiveProperties(minimize=True),
    },
    # We will constrain the number of possible clusters and points that are labeled as noise
    outcome_constraints=["n_clusters <= 30", "n_clusters >= 15"],
    overwrite_existing_experiment=True,
)

# Run 30 trials
for i in range(30):
    parameterization, trial_index = ax_client.get_next_trial()
    ax_client.complete_trial(
        trial_index=trial_index,
        raw_data=hdbscan_evaluation_function(parameterization),
    )
# Out:
# [INFO 05-19 10:37:22] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# [WARNING 05-19 10:37:22] ax.service.ax_client: Random seed set to 0. Note that this setting only affects the Sobol quasi-random generator and BoTorch-powered Bayesian optimization models. For the latter models, setting random seed to the same number for two optimizations will make the generated trials similar, but not exactly the same, and over time the trials will diverge more.
# [INFO 05-19 10:37:22] ax.service.utils.instantiation: Due to non-specification, we will use the heuristic for selecting objective thresholds.
# [INFO 05-19 10:37:22] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='min_samples', parameter_type=INT, range=[1, 60]), RangeParameter(name='min_cluster_size', parameter_type=INT, range=[5, 100]), RangeParameter(name='cluster_selection_epsilon', parameter_type=FLOAT, range=[0.1, 1.5]), ChoiceParameter(name='metric', parameter_type=STRING, values=['euclidean', 'manhattan', 'canberra', 'braycurtis'], is_ordered=False, sort_values=False)], parameter_constraints=[]).
# [INFO 05-19 10:37:22] ax.modelbridge.dispatch_utils: Using Bayesian optimization with a categorical kernel for improved performance with a large number of unordered categorical parameters.
# [INFO 05-19 10:37:22] ax.modelbridge.dispatch_utils: Calculating the number of remaining initialization trials based on num_initialization_trials=None max_initialization_trials=None num_tunable_parameters=4 num_trials=None use_batch_trials=False
# [INFO 05-19 10:37:22] ax.modelbridge.dispatch_utils: calculated num_initialization_trials=8
# [INFO 05-19 10:37:22] ax.modelbridge.dispatch_utils: num_completed_initialization_trials=0 num_remaining_initialization_trials=8
# [INFO 05-19 10:37:22] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+BO_MIXED', steps=[Sobol for 8 trials, BO_MIXED for subsequent trials]). Iterations after 8 will take longer to generate due to model-fitting.
# [INFO 05-19 10:37:22] ax.service.ax_client: Generated new trial 0 with parameters {'min_samples': 29, 'min_cluster_size': 61, 'cluster_selection_epsilon': 0.792271, 'metric': 'canberra'}.
# [INFO 05-19 10:37:49] ax.service.ax_client: Completed trial 0 with data: {'n_noise': (270, 0), 'n_clusters': (15, 0), 'silhouette': (0.46330172, 0), 'calinski_harabasz': (31375.495922, 0), 'davies_bouldin': (0.547937, 0)}.
# [INFO 05-19 10:37:49] ax.service.ax_client: Generated new trial 1 with parameters {'min_samples': 48, 'min_cluster_size': 35, 'cluster_selection_epsilon': 1.11402, 'metric': 'euclidean'}.
# [INFO 05-19 10:38:06] ax.service.ax_client: Completed trial 1 with data: {'n_noise': (100, 0), 'n_clusters': (12, 0), 'silhouette': (0.62026024, 0), 'calinski_harabasz': (34831.999579, 0), 'davies_bouldin': (0.411765, 0)}.
# [INFO 05-19 10:38:06] ax.service.ax_client: Generated new trial 2 with parameters {'min_samples': 39, 'min_cluster_size': 98, 'cluster_selection_epsilon': 0.10086, 'metric': 'euclidean'}.
# [INFO 05-19 10:38:18] ax.service.ax_client: Completed trial 2 with data: {'n_noise': (5440, 0), 'n_clusters': (28, 0), 'silhouette': (0.68632066, 0), 'calinski_harabasz': (104854.452125, 0), 'davies_bouldin': (0.52598, 0)}.
# [INFO 05-19 10:38:18] ax.service.ax_client: Generated new trial 3 with parameters {'min_samples': 6, 'min_cluster_size': 28, 'cluster_selection_epsilon': 1.192848, 'metric': 'braycurtis'}.
# [INFO 05-19 10:38:43] ax.service.ax_client: Completed trial 3 with data: {'n_noise': (14, 0), 'n_clusters': (2, 0), 'silhouette': (0.37019125, 0), 'calinski_harabasz': (8250.699487, 0), 'davies_bouldin': (0.697135, 0)}.
# [INFO 05-19 10:38:43] ax.service.ax_client: Generated new trial 4 with parameters {'min_samples': 11, 'min_cluster_size': 82, 'cluster_selection_epsilon': 0.885242, 'metric': 'braycurtis'}.
# [INFO 05-19 10:39:08] ax.service.ax_client: Completed trial 4 with data: {'n_noise': (14, 0), 'n_clusters': (2, 0), 'silhouette': (0.37019125, 0), 'calinski_harabasz': (8250.699487, 0), 'davies_bouldin': (0.697135, 0)}.
# [INFO 05-19 10:39:08] ax.service.ax_client: Generated new trial 5 with parameters {'min_samples': 37, 'min_cluster_size': 9, 'cluster_selection_epsilon': 0.496054, 'metric': 'euclidean'}.
# [INFO 05-19 10:39:23] ax.service.ax_client: Completed trial 5 with data: {'n_noise': (1605, 0), 'n_clusters': (19, 0), 'silhouette': (0.54016995, 0), 'calinski_harabasz': (49814.469988, 0), 'davies_bouldin': (0.394327, 0)}.
# [INFO 05-19 10:39:23] ax.service.ax_client: Generated new trial 6 with parameters {'min_samples': 57, 'min_cluster_size': 66, 'cluster_selection_epsilon': 1.418826, 'metric': 'braycurtis'}.
# [INFO 05-19 10:39:45] ax.service.ax_client: Completed trial 6 with data: {'n_noise': (14, 0), 'n_clusters': (2, 0), 'silhouette': (0.37019125, 0), 'calinski_harabasz': (8250.699487, 0), 'davies_bouldin': (0.697135, 0)}.
# [INFO 05-19 10:39:45] ax.service.ax_client: Generated new trial 7 with parameters {'min_samples': 16, 'min_cluster_size': 43, 'cluster_selection_epsilon': 0.399877, 'metric': 'manhattan'}.
# [INFO 05-19 10:39:59] ax.service.ax_client: Completed trial 7 with data: {'n_noise': (4001, 0), 'n_clusters': (59, 0), 'silhouette': (0.689196, 0), 'calinski_harabasz': (52253.824934, 0), 'davies_bouldin': (0.593776, 0)}.
# [WARNING 05-19 10:39:59] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 10:40:14] ax.service.ax_client: Generated new trial 8 with parameters {'min_samples': 60, 'min_cluster_size': 49, 'cluster_selection_epsilon': 0.337675, 'metric': 'euclidean'}.
# [INFO 05-19 10:40:27] ax.service.ax_client: Completed trial 8 with data: {'n_noise': (3871, 0), 'n_clusters': (25, 0), 'silhouette': (0.6983598, 0), 'calinski_harabasz': (105558.428035, 0), 'davies_bouldin': (0.431728, 0)}.
# [WARNING 05-19 10:40:27] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 10:40:51] ax.service.ax_client: Generated new trial 9 with parameters {'min_samples': 60, 'min_cluster_size': 47, 'cluster_selection_epsilon': 0.574417, 'metric': 'euclidean'}.
# [INFO 05-19 10:41:06] ax.service.ax_client: Completed trial 9 with data: {'n_noise': (1929, 0), 'n_clusters': (15, 0), 'silhouette': (0.65071756, 0), 'calinski_harabasz': (68206.950939, 0), 'davies_bouldin': (0.372172, 0)}.
# [WARNING 05-19 10:41:06] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 10:41:39] ax.service.ax_client: Generated new trial 10 with parameters {'min_samples': 60, 'min_cluster_size': 61, 'cluster_selection_epsilon': 0.567088, 'metric': 'euclidean'}.
# [INFO 05-19 10:41:55] ax.service.ax_client: Completed trial 10 with data: {'n_noise': (1022, 0), 'n_clusters': (14, 0), 'silhouette': (0.63241524, 0), 'calinski_harabasz': (65269.282902, 0), 'davies_bouldin': (0.379173, 0)}.
# [WARNING 05-19 10:41:55] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 10:42:24] ax.service.ax_client: Generated new trial 11 with parameters {'min_samples': 60, 'min_cluster_size': 60, 'cluster_selection_epsilon': 0.480578, 'metric': 'euclidean'}.
# [INFO 05-19 10:42:38] ax.service.ax_client: Completed trial 11 with data: {'n_noise': (2285, 0), 'n_clusters': (17, 0), 'silhouette': (0.66309893, 0), 'calinski_harabasz': (110260.047622, 0), 'davies_bouldin': (0.416209, 0)}.
# [WARNING 05-19 10:42:39] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 10:43:06] ax.service.ax_client: Generated new trial 12 with parameters {'min_samples': 60, 'min_cluster_size': 29, 'cluster_selection_epsilon': 0.610007, 'metric': 'euclidean'}.
# [INFO 05-19 10:43:21] ax.service.ax_client: Completed trial 12 with data: {'n_noise': (1022, 0), 'n_clusters': (14, 0), 'silhouette': (0.63241524, 0), 'calinski_harabasz': (65269.282902, 0), 'davies_bouldin': (0.379173, 0)}.
# [WARNING 05-19 10:43:21] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 10:44:29] ax.service.ax_client: Generated new trial 13 with parameters {'min_samples': 60, 'min_cluster_size': 47, 'cluster_selection_epsilon': 0.571207, 'metric': 'euclidean'}.
# [INFO 05-19 10:44:44] ax.service.ax_client: Completed trial 13 with data: {'n_noise': (1929, 0), 'n_clusters': (15, 0), 'silhouette': (0.65071756, 0), 'calinski_harabasz': (68206.950939, 0), 'davies_bouldin': (0.372172, 0)}.
# [WARNING 05-19 10:44:44] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 10:45:34] ax.service.ax_client: Generated new trial 14 with parameters {'min_samples': 48, 'min_cluster_size': 52, 'cluster_selection_epsilon': 0.652432, 'metric': 'euclidean'}.
# [INFO 05-19 10:45:49] ax.service.ax_client: Completed trial 14 with data: {'n_noise': (1341, 0), 'n_clusters': (14, 0), 'silhouette': (0.6412278, 0), 'calinski_harabasz': (67750.042814, 0), 'davies_bouldin': (0.370786, 0)}.
# [WARNING 05-19 10:45:49] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 10:46:28] ax.service.ax_client: Generated new trial 15 with parameters {'min_samples': 60, 'min_cluster_size': 29, 'cluster_selection_epsilon': 0.442924, 'metric': 'euclidean'}.
# [INFO 05-19 10:46:42] ax.service.ax_client: Completed trial 15 with data: {'n_noise': (2454, 0), 'n_clusters': (20, 0), 'silhouette': (0.67760634, 0), 'calinski_harabasz': (102003.973475, 0), 'davies_bouldin': (0.409964, 0)}.
# [WARNING 05-19 10:46:42] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 10:47:55] ax.service.ax_client: Generated new trial 16 with parameters {'min_samples': 60, 'min_cluster_size': 77, 'cluster_selection_epsilon': 0.447398, 'metric': 'euclidean'}.
# [INFO 05-19 10:48:09] ax.service.ax_client: Completed trial 16 with data: {'n_noise': (2511, 0), 'n_clusters': (18, 0), 'silhouette': (0.6825029, 0), 'calinski_harabasz': (112606.12049, 0), 'davies_bouldin': (0.418814, 0)}.
# [WARNING 05-19 10:48:09] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 10:49:01] ax.service.ax_client: Generated new trial 17 with parameters {'min_samples': 13, 'min_cluster_size': 41, 'cluster_selection_epsilon': 0.674771, 'metric': 'euclidean'}.
# [INFO 05-19 10:49:17] ax.service.ax_client: Completed trial 17 with data: {'n_noise': (254, 0), 'n_clusters': (16, 0), 'silhouette': (0.57057434, 0), 'calinski_harabasz': (27007.497392, 0), 'davies_bouldin': (0.52684, 0)}.
# [WARNING 05-19 10:49:17] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 10:50:44] ax.service.ax_client: Generated new trial 18 with parameters {'min_samples': 60, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.823511, 'metric': 'euclidean'}.
# [INFO 05-19 10:51:00] ax.service.ax_client: Completed trial 18 with data: {'n_noise': (1022, 0), 'n_clusters': (13, 0), 'silhouette': (0.6334627, 0), 'calinski_harabasz': (70401.212458, 0), 'davies_bouldin': (0.385729, 0)}.
# [WARNING 05-19 10:51:00] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 10:52:04] ax.service.ax_client: Generated new trial 19 with parameters {'min_samples': 49, 'min_cluster_size': 41, 'cluster_selection_epsilon': 0.585896, 'metric': 'euclidean'}.
# [INFO 05-19 10:52:19] ax.service.ax_client: Completed trial 19 with data: {'n_noise': (1508, 0), 'n_clusters': (16, 0), 'silhouette': (0.5848456, 0), 'calinski_harabasz': (61029.142952, 0), 'davies_bouldin': (0.398364, 0)}.
# [WARNING 05-19 10:52:19] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 10:53:03] ax.service.ax_client: Generated new trial 20 with parameters {'min_samples': 60, 'min_cluster_size': 100, 'cluster_selection_epsilon': 1.116388, 'metric': 'euclidean'}.
# [INFO 05-19 10:53:20] ax.service.ax_client: Completed trial 20 with data: {'n_noise': (104, 0), 'n_clusters': (11, 0), 'silhouette': (0.62130344, 0), 'calinski_harabasz': (38235.948276, 0), 'davies_bouldin': (0.410603, 0)}.
# [WARNING 05-19 10:53:20] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 10:54:10] ax.service.ax_client: Generated new trial 21 with parameters {'min_samples': 60, 'min_cluster_size': 5, 'cluster_selection_epsilon': 0.572264, 'metric': 'euclidean'}.
# [INFO 05-19 10:54:25] ax.service.ax_client: Completed trial 21 with data: {'n_noise': (1886, 0), 'n_clusters': (17, 0), 'silhouette': (0.5886426, 0), 'calinski_harabasz': (59801.17212, 0), 'davies_bouldin': (0.395183, 0)}.
# [WARNING 05-19 10:54:25] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 10:55:32] ax.service.ax_client: Generated new trial 22 with parameters {'min_samples': 48, 'min_cluster_size': 5, 'cluster_selection_epsilon': 0.68579, 'metric': 'euclidean'}.
# [INFO 05-19 10:55:48] ax.service.ax_client: Completed trial 22 with data: {'n_noise': (956, 0), 'n_clusters': (15, 0), 'silhouette': (0.54040134, 0), 'calinski_harabasz': (31042.824497, 0), 'davies_bouldin': (0.492939, 0)}.
# [WARNING 05-19 10:55:48] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 10:57:00] ax.service.ax_client: Generated new trial 23 with parameters {'min_samples': 46, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.538404, 'metric': 'euclidean'}.
# [INFO 05-19 10:57:16] ax.service.ax_client: Completed trial 23 with data: {'n_noise': (1327, 0), 'n_clusters': (13, 0), 'silhouette': (0.6418646, 0), 'calinski_harabasz': (73001.101721, 0), 'davies_bouldin': (0.378069, 0)}.
# [WARNING 05-19 10:57:16] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 10:59:07] ax.service.ax_client: Generated new trial 24 with parameters {'min_samples': 48, 'min_cluster_size': 80, 'cluster_selection_epsilon': 0.487189, 'metric': 'euclidean'}.
# [INFO 05-19 10:59:22] ax.service.ax_client: Completed trial 24 with data: {'n_noise': (1341, 0), 'n_clusters': (13, 0), 'silhouette': (0.64228433, 0), 'calinski_harabasz': (73061.451089, 0), 'davies_bouldin': (0.377226, 0)}.
# [WARNING 05-19 10:59:22] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 11:00:20] ax.service.ax_client: Generated new trial 25 with parameters {'min_samples': 60, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.525606, 'metric': 'euclidean'}.
# [INFO 05-19 11:00:35] ax.service.ax_client: Completed trial 25 with data: {'n_noise': (2264, 0), 'n_clusters': (14, 0), 'silhouette': (0.70084965, 0), 'calinski_harabasz': (115172.750839, 0), 'davies_bouldin': (0.36391, 0)}.
# [WARNING 05-19 11:00:35] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 11:01:22] ax.service.ax_client: Generated new trial 26 with parameters {'min_samples': 60, 'min_cluster_size': 59, 'cluster_selection_epsilon': 0.802971, 'metric': 'euclidean'}.
# [INFO 05-19 11:01:38] ax.service.ax_client: Completed trial 26 with data: {'n_noise': (1022, 0), 'n_clusters': (14, 0), 'silhouette': (0.63241524, 0), 'calinski_harabasz': (65269.282902, 0), 'davies_bouldin': (0.379173, 0)}.
# [WARNING 05-19 11:01:38] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 11:02:53] ax.service.ax_client: Generated new trial 27 with parameters {'min_samples': 60, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.448317, 'metric': 'euclidean'}.
# [INFO 05-19 11:03:07] ax.service.ax_client: Completed trial 27 with data: {'n_noise': (2509, 0), 'n_clusters': (17, 0), 'silhouette': (0.68451375, 0), 'calinski_harabasz': (117855.830715, 0), 'davies_bouldin': (0.42482, 0)}.
# [WARNING 05-19 11:03:07] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 11:04:29] ax.service.ax_client: Generated new trial 28 with parameters {'min_samples': 60, 'min_cluster_size': 46, 'cluster_selection_epsilon': 0.55822, 'metric': 'euclidean'}.
# [INFO 05-19 11:04:44] ax.service.ax_client: Completed trial 28 with data: {'n_noise': (1929, 0), 'n_clusters': (15, 0), 'silhouette': (0.65071756, 0), 'calinski_harabasz': (68206.950939, 0), 'davies_bouldin': (0.372172, 0)}.
# [WARNING 05-19 11:04:44] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-19 11:05:23] ax.service.ax_client: Generated new trial 29 with parameters {'min_samples': 1, 'min_cluster_size': 100, 'cluster_selection_epsilon': 1.5, 'metric': 'euclidean'}.
# [INFO 05-19 11:05:41] ax.service.ax_client: Completed trial 29 with data: {'n_noise': (73, 0), 'n_clusters': (10, 0), 'silhouette': (0.5710425, 0), 'calinski_harabasz': (30170.222381, 0), 'davies_bouldin': (0.42413, 0)}.

# %%
# Retrieve the best parameters
best_param_dict = ax_client.get_pareto_optimal_parameters()

# Display the best parameters and their evaluation metrics
summary_table = []
for exp_idx, summary in best_param_dict.items():
    params, (eval_metrics, sems) = summary
    row = {"Experiment": exp_idx, **params, **eval_metrics}
    summary_table.append(row)

summary_table = pd.DataFrame(summary_table)
int_cols = ["n_clusters", "n_noise"]
summary_table[int_cols] = summary_table[int_cols].astype(int)

param_cols = ["min_samples", "min_cluster_size", "cluster_selection_epsilon", "metric"]
obj_cols = [
    "n_clusters",
    "n_noise",
    "silhouette",
    "calinski_harabasz",
    "davies_bouldin",
]

param_df = summary_table[param_cols]
obj_df = summary_table[obj_cols]

# Concatenate the grouped columns
df_summary = pd.concat(
    [param_df, obj_df], axis=1, keys=["Hyperparameters", "Objectives"]
)
df_summary.index = summary_table["Experiment"]
df_summary
# Out:
# [INFO 05-19 16:20:00] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 05-19 16:20:00] ax.service.utils.best_point: Using inferred objective thresholds: [ObjectiveThreshold(calinski_harabasz >= 18515.715795196178), ObjectiveThreshold(davies_bouldin <= 0.5655129241684163), ObjectiveThreshold(n_noise <= 2819.0235794422542), ObjectiveThreshold(silhouette >= 0.44177356250043925)], as objective thresholds were not specified as part of the optimization configuration on the experiment.
#            Hyperparameters
#                min_samples min_cluster_size cluster_selection_epsilon
# Experiment
# 0                       29               61                  0.792271  \
# 11                      60               60                  0.480578
# 15                      60               29                  0.442924
# 16                      60               77                  0.447398
# 17                      13               41                  0.674771
# 19                      49               41                  0.585896
# 21                      60                5                  0.572264
# 22                      48                5                  0.685790
# 27                      60              100                  0.448317
# 28                      60               46                  0.558220
#
#                       Objectives
#                metric n_clusters n_noise silhouette calinski_harabasz
# Experiment
# 0            canberra         15     330   0.464322      30807.981322  \
# 11          euclidean         16    2239   0.671799      96756.249930
# 15          euclidean         20    2592   0.652893      93385.555137
# 16          euclidean         17    2512   0.683756     107706.481912
# 17          euclidean         15     363   0.570803      27143.142080
# 19          euclidean         15    1355   0.613641      58374.998240
# 21          euclidean         16    1688   0.592933      61005.738192
# 22          euclidean         15     997   0.551328      39512.495621
# 27          euclidean         16    2490   0.689801     113417.404928
# 28          euclidean         15    1722   0.650908      76575.607392
#
#
#            davies_bouldin
# Experiment
# 0                0.547937
# 11               0.416208
# 15               0.409964
# 16               0.418814
# 17               0.526840
# 19               0.398364
# 21               0.395183
# 22               0.492939
# 27               0.424819
# 28               0.372175

# %%
# Create a 2D UMAP embedding of the data
reducer_2d = umap.UMAP(random_state=0)
embedding_2d = reducer_2d.fit_transform(data)

# %%
best_idx = 15
best_params = best_param_dict[best_idx][0]

# Perform HDBSCAN clustering on the data with the best parameters
clusterer = hdbscan.HDBSCAN(**best_params)
clusterer.fit(reduced_data)
# Out:
# HDBSCAN(cluster_selection_epsilon=0.44292351550449616, min_cluster_size=29,
#         min_samples=60)

# %%
emb_df = pd.DataFrame(embedding_2d, columns=["x", "y"])
emb_df["failureType"] = df["failureType"].values
emb_df["waferMap"] = df["waferMap"].values
emb_df["cluster"] = pd.Series(clusterer.labels_).astype("category").values
emb_df.sort_values("cluster", inplace=True)

# %%
fig = px.scatter(
    emb_df,
    x="x",
    y="y",
    color="cluster",
    # color_discrete_sequence=px.colors.qualitative.Light24,
    color_discrete_sequence=mpn65_palette(),
    width=800,
    height=600,
    template="simple_white",
    color_discrete_map={-1: "lightgray"},
)
# fig.update_traces(
#     marker=dict(
#         line=dict(
#             width=emb_df["cluster"].map(lambda x: 0.5 if x < 0 else 0).values,
#             color="white",
#         )
#     )
# )
fig.show()
