# %%
import os
import warnings

import hdbscan
import numpy as np
import pandas as pd
import plotly.express as px
import seaborn as sns
import umap
from ax.plot.pareto_frontier import plot_pareto_frontier
from ax.plot.pareto_utils import compute_posterior_pareto_frontier
from ax.service.ax_client import AxClient
from ax.service.managed_loop import optimize
from ax.service.utils.instantiation import ObjectiveProperties
from sklearn.metrics import (
    calinski_harabasz_score,
    davies_bouldin_score,
    silhouette_score,
)

from ssl_wafermap.utilities.plotting import create_subplots

warnings.filterwarnings("ignore")

# %%
df = pd.read_pickle("../data/interim/model_preds/SwaV_preds_full.pkl.xz")
cols = df.columns.difference(["failureType", "failureCode", "waferMap"])
data = df[cols].values

# %%
reducer = umap.UMAP(
    random_state=0,
    n_neighbors=30,
    min_dist=0,
    n_components=50,
    densmap=True,
    dens_lambda=0.1,
)
reduced_data = reducer.fit_transform(data)
# Out:
# UMAP(dens_lambda=0.2, densmap=True, min_dist=0, n_components=50, n_neighbors=30, random_state=0, verbose=True)
# Thu May 18 17:18:58 2023 Construct fuzzy simplicial set
# Thu May 18 17:18:58 2023 Finding Nearest Neighbors
# Thu May 18 17:18:58 2023 Building RP forest with 15 trees
# Thu May 18 17:18:59 2023 NN descent for 15 iterations
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	Stopping threshold met -- exiting after 3 iterations
# Thu May 18 17:19:17 2023 Finished Nearest Neighbor Search
# Thu May 18 17:19:22 2023 Construct embedding
# Thu May 18 17:19:35 2023 Computing original densities
# Epochs completed:   0%|            0/400 [00:00]
# Thu May 18 17:23:54 2023 Finished embedding

# %%
def hdbscan_evaluation_function(parameterization):
    # Perform HDBSCAN clustering on the data with given parameters
    clusterer = hdbscan.HDBSCAN(
        min_samples=parameterization.get("min_samples"),
        min_cluster_size=parameterization.get("min_cluster_size"),
        cluster_selection_epsilon=parameterization.get("cluster_selection_epsilon"),
        metric=parameterization.get("metric"),
    )
    # clusterer.fit(data)
    clusterer.fit(reduced_data)

    # Calculate the number of clusters and points labeled as noise to constrain the optimization
    labels = clusterer.labels_
    n_clusters = labels.max() + 1
    n_noise = (labels == -1).sum()

    # Compute the silhouette score, Calinski-Harabasz score, and Davies-Bouldin score
    # These should be on the subset of the data NOT labeled as noise (i.e. labels != -1)
    subset_data, subset_labels = reduced_data[labels != -1], labels[labels != -1]
    silhouette = silhouette_score(subset_data, subset_labels)
    calinski_harabasz = calinski_harabasz_score(subset_data, subset_labels)
    davies_bouldin = davies_bouldin_score(subset_data, subset_labels)

    # Return the evaluation metrics and outcome constraints
    # These are tuples of the metrics with the SEM
    return {
        "n_noise": (n_noise, 0),
        "n_clusters": (n_clusters, 0),
        "silhouette": (silhouette, 0),
        "calinski_harabasz": (calinski_harabasz, 0),
        "davies_bouldin": (davies_bouldin, 0),
    }


# Create a search space for the hyperparameters
parameters = [
    {"name": "min_samples", "type": "range", "bounds": [1, 60], "value_type": "int"},
    {
        "name": "min_cluster_size",
        "type": "range",
        "bounds": [5, 100],
        "value_type": "int",
    },
    {
        "name": "cluster_selection_epsilon",
        "type": "range",
        "bounds": [0.1, 1.5],
        "value_type": "float",
    },
    {
        "name": "metric",
        "type": "choice",
        "values": ["euclidean", "manhattan", "canberra", "braycurtis"],
        "value_type": "str",
        "is_ordered": False,
    },
]


# Initialize the optimization client
ax_client = AxClient(random_seed=0)
ax_client.create_experiment(
    parameters=parameters,
    # Optimize cluster evaluation metrics while minimizing the number of noise points
    objectives={
        "silhouette": ObjectiveProperties(minimize=False),
        "calinski_harabasz": ObjectiveProperties(minimize=False),
        "davies_bouldin": ObjectiveProperties(minimize=True),
        "n_noise": ObjectiveProperties(minimize=True),
    },
    # We will constrain the number of possible clusters and points that are labeled as noise
    outcome_constraints=["n_clusters <= 30", "n_clusters >= 15"],
    overwrite_existing_experiment=True,
)

# Run 30 trials
for i in range(30):
    parameterization, trial_index = ax_client.get_next_trial()
    ax_client.complete_trial(
        trial_index=trial_index,
        raw_data=hdbscan_evaluation_function(parameterization),
    )
# Out:
# [INFO 05-18 19:38:37] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# [WARNING 05-18 19:38:37] ax.service.ax_client: Random seed set to 0. Note that this setting only affects the Sobol quasi-random generator and BoTorch-powered Bayesian optimization models. For the latter models, setting random seed to the same number for two optimizations will make the generated trials similar, but not exactly the same, and over time the trials will diverge more.
# [INFO 05-18 19:38:37] ax.service.utils.instantiation: Due to non-specification, we will use the heuristic for selecting objective thresholds.
# [INFO 05-18 19:38:37] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='min_samples', parameter_type=INT, range=[1, 60]), RangeParameter(name='min_cluster_size', parameter_type=INT, range=[5, 100]), RangeParameter(name='cluster_selection_epsilon', parameter_type=FLOAT, range=[0.1, 1.5]), ChoiceParameter(name='metric', parameter_type=STRING, values=['euclidean', 'manhattan', 'canberra', 'braycurtis'], is_ordered=False, sort_values=False)], parameter_constraints=[]).
# [INFO 05-18 19:38:37] ax.modelbridge.dispatch_utils: Using Bayesian optimization with a categorical kernel for improved performance with a large number of unordered categorical parameters.
# [INFO 05-18 19:38:37] ax.modelbridge.dispatch_utils: Calculating the number of remaining initialization trials based on num_initialization_trials=None max_initialization_trials=None num_tunable_parameters=4 num_trials=None use_batch_trials=False
# [INFO 05-18 19:38:37] ax.modelbridge.dispatch_utils: calculated num_initialization_trials=8
# [INFO 05-18 19:38:37] ax.modelbridge.dispatch_utils: num_completed_initialization_trials=0 num_remaining_initialization_trials=8
# [INFO 05-18 19:38:37] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+BO_MIXED', steps=[Sobol for 8 trials, BO_MIXED for subsequent trials]). Iterations after 8 will take longer to generate due to model-fitting.
# [INFO 05-18 19:38:37] ax.service.ax_client: Generated new trial 0 with parameters {'min_samples': 29, 'min_cluster_size': 61, 'cluster_selection_epsilon': 0.792271, 'metric': 'canberra'}.
# [INFO 05-18 19:39:12] ax.service.ax_client: Completed trial 0 with data: {'n_noise': (688, 0), 'n_clusters': (16, 0), 'silhouette': (0.4588846, 0), 'calinski_harabasz': (29135.285946, 0), 'davies_bouldin': (0.56554, 0)}.
# [INFO 05-18 19:39:12] ax.service.ax_client: Generated new trial 1 with parameters {'min_samples': 48, 'min_cluster_size': 35, 'cluster_selection_epsilon': 1.11402, 'metric': 'euclidean'}.
# [INFO 05-18 19:39:30] ax.service.ax_client: Completed trial 1 with data: {'n_noise': (169, 0), 'n_clusters': (12, 0), 'silhouette': (0.602994, 0), 'calinski_harabasz': (32999.557787, 0), 'davies_bouldin': (0.42946, 0)}.
# [INFO 05-18 19:39:30] ax.service.ax_client: Generated new trial 2 with parameters {'min_samples': 39, 'min_cluster_size': 98, 'cluster_selection_epsilon': 0.10086, 'metric': 'euclidean'}.
# [INFO 05-18 19:39:44] ax.service.ax_client: Completed trial 2 with data: {'n_noise': (5824, 0), 'n_clusters': (26, 0), 'silhouette': (0.67270976, 0), 'calinski_harabasz': (101466.549927, 0), 'davies_bouldin': (0.552011, 0)}.
# [INFO 05-18 19:39:44] ax.service.ax_client: Generated new trial 3 with parameters {'min_samples': 6, 'min_cluster_size': 28, 'cluster_selection_epsilon': 1.192848, 'metric': 'braycurtis'}.
# [INFO 05-18 19:40:16] ax.service.ax_client: Completed trial 3 with data: {'n_noise': (25, 0), 'n_clusters': (2, 0), 'silhouette': (0.36828506, 0), 'calinski_harabasz': (8234.848925, 0), 'davies_bouldin': (0.712757, 0)}.
# [INFO 05-18 19:40:16] ax.service.ax_client: Generated new trial 4 with parameters {'min_samples': 11, 'min_cluster_size': 82, 'cluster_selection_epsilon': 0.885242, 'metric': 'braycurtis'}.
# [INFO 05-18 19:40:46] ax.service.ax_client: Completed trial 4 with data: {'n_noise': (27, 0), 'n_clusters': (2, 0), 'silhouette': (0.36829448, 0), 'calinski_harabasz': (8234.949117, 0), 'davies_bouldin': (0.712754, 0)}.
# [INFO 05-18 19:40:46] ax.service.ax_client: Generated new trial 5 with parameters {'min_samples': 37, 'min_cluster_size': 9, 'cluster_selection_epsilon': 0.496054, 'metric': 'euclidean'}.
# [INFO 05-18 19:41:02] ax.service.ax_client: Completed trial 5 with data: {'n_noise': (2236, 0), 'n_clusters': (20, 0), 'silhouette': (0.5641785, 0), 'calinski_harabasz': (56118.805424, 0), 'davies_bouldin': (0.439633, 0)}.
# [INFO 05-18 19:41:02] ax.service.ax_client: Generated new trial 6 with parameters {'min_samples': 57, 'min_cluster_size': 66, 'cluster_selection_epsilon': 1.418826, 'metric': 'braycurtis'}.
# [INFO 05-18 19:41:31] ax.service.ax_client: Completed trial 6 with data: {'n_noise': (31, 0), 'n_clusters': (2, 0), 'silhouette': (0.3683359, 0), 'calinski_harabasz': (8235.803733, 0), 'davies_bouldin': (0.712724, 0)}.
# [INFO 05-18 19:41:31] ax.service.ax_client: Generated new trial 7 with parameters {'min_samples': 16, 'min_cluster_size': 43, 'cluster_selection_epsilon': 0.399877, 'metric': 'manhattan'}.
# [INFO 05-18 19:41:45] ax.service.ax_client: Completed trial 7 with data: {'n_noise': (4650, 0), 'n_clusters': (57, 0), 'silhouette': (0.6858194, 0), 'calinski_harabasz': (48032.164176, 0), 'davies_bouldin': (0.625205, 0)}.
# [WARNING 05-18 19:41:45] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 19:42:02] ax.service.ax_client: Generated new trial 8 with parameters {'min_samples': 40, 'min_cluster_size': 38, 'cluster_selection_epsilon': 0.428733, 'metric': 'euclidean'}.
# [INFO 05-18 19:42:18] ax.service.ax_client: Completed trial 8 with data: {'n_noise': (2181, 0), 'n_clusters': (19, 0), 'silhouette': (0.6183617, 0), 'calinski_harabasz': (80449.652986, 0), 'davies_bouldin': (0.46109, 0)}.
# [WARNING 05-18 19:42:18] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 19:42:48] ax.service.ax_client: Generated new trial 9 with parameters {'min_samples': 51, 'min_cluster_size': 30, 'cluster_selection_epsilon': 0.493784, 'metric': 'euclidean'}.
# [INFO 05-18 19:43:04] ax.service.ax_client: Completed trial 9 with data: {'n_noise': (2381, 0), 'n_clusters': (17, 0), 'silhouette': (0.57158583, 0), 'calinski_harabasz': (88586.088713, 0), 'davies_bouldin': (0.551403, 0)}.
# [WARNING 05-18 19:43:04] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 19:43:32] ax.service.ax_client: Generated new trial 10 with parameters {'min_samples': 40, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.473592, 'metric': 'euclidean'}.
# [INFO 05-18 19:43:48] ax.service.ax_client: Completed trial 10 with data: {'n_noise': (2186, 0), 'n_clusters': (14, 0), 'silhouette': (0.6723587, 0), 'calinski_harabasz': (104847.152718, 0), 'davies_bouldin': (0.43856, 0)}.
# [WARNING 05-18 19:43:48] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 19:44:09] ax.service.ax_client: Generated new trial 11 with parameters {'min_samples': 39, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.409968, 'metric': 'euclidean'}.
# [INFO 05-18 19:44:25] ax.service.ax_client: Completed trial 11 with data: {'n_noise': (2642, 0), 'n_clusters': (15, 0), 'silhouette': (0.6787627, 0), 'calinski_harabasz': (109111.481559, 0), 'davies_bouldin': (0.427994, 0)}.
# [WARNING 05-18 19:44:25] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 19:44:36] ax.service.ax_client: Generated new trial 12 with parameters {'min_samples': 38, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.402027, 'metric': 'euclidean'}.
# [INFO 05-18 19:44:52] ax.service.ax_client: Completed trial 12 with data: {'n_noise': (2462, 0), 'n_clusters': (15, 0), 'silhouette': (0.67572373, 0), 'calinski_harabasz': (107664.310446, 0), 'davies_bouldin': (0.431572, 0)}.
# [WARNING 05-18 19:44:52] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 19:45:16] ax.service.ax_client: Generated new trial 13 with parameters {'min_samples': 39, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.399972, 'metric': 'euclidean'}.
# [INFO 05-18 19:45:32] ax.service.ax_client: Completed trial 13 with data: {'n_noise': (2642, 0), 'n_clusters': (15, 0), 'silhouette': (0.6787627, 0), 'calinski_harabasz': (109111.481559, 0), 'davies_bouldin': (0.427994, 0)}.
# [WARNING 05-18 19:45:32] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 19:46:10] ax.service.ax_client: Generated new trial 14 with parameters {'min_samples': 40, 'min_cluster_size': 98, 'cluster_selection_epsilon': 0.388617, 'metric': 'euclidean'}.
# [INFO 05-18 19:46:26] ax.service.ax_client: Completed trial 14 with data: {'n_noise': (2607, 0), 'n_clusters': (15, 0), 'silhouette': (0.67966026, 0), 'calinski_harabasz': (109552.522293, 0), 'davies_bouldin': (0.428259, 0)}.
# [WARNING 05-18 19:46:26] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 19:46:34] ax.service.ax_client: Generated new trial 15 with parameters {'min_samples': 41, 'min_cluster_size': 98, 'cluster_selection_epsilon': 0.401385, 'metric': 'euclidean'}.
# [INFO 05-18 19:46:50] ax.service.ax_client: Completed trial 15 with data: {'n_noise': (2392, 0), 'n_clusters': (14, 0), 'silhouette': (0.67664224, 0), 'calinski_harabasz': (107000.193344, 0), 'davies_bouldin': (0.434545, 0)}.
# [WARNING 05-18 19:46:50] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 19:47:37] ax.service.ax_client: Generated new trial 16 with parameters {'min_samples': 39, 'min_cluster_size': 90, 'cluster_selection_epsilon': 0.387572, 'metric': 'euclidean'}.
# [INFO 05-18 19:47:53] ax.service.ax_client: Completed trial 16 with data: {'n_noise': (2642, 0), 'n_clusters': (15, 0), 'silhouette': (0.6787627, 0), 'calinski_harabasz': (109111.481559, 0), 'davies_bouldin': (0.427994, 0)}.
# [WARNING 05-18 19:47:53] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 19:48:19] ax.service.ax_client: Generated new trial 17 with parameters {'min_samples': 39, 'min_cluster_size': 98, 'cluster_selection_epsilon': 0.37049, 'metric': 'euclidean'}.
# [INFO 05-18 19:48:35] ax.service.ax_client: Completed trial 17 with data: {'n_noise': (3013, 0), 'n_clusters': (17, 0), 'silhouette': (0.6981966, 0), 'calinski_harabasz': (117952.919828, 0), 'davies_bouldin': (0.446011, 0)}.
# [WARNING 05-18 19:48:35] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 19:49:36] ax.service.ax_client: Generated new trial 18 with parameters {'min_samples': 40, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.378457, 'metric': 'euclidean'}.
# [INFO 05-18 19:49:52] ax.service.ax_client: Completed trial 18 with data: {'n_noise': (2848, 0), 'n_clusters': (16, 0), 'silhouette': (0.7014802, 0), 'calinski_harabasz': (110691.998815, 0), 'davies_bouldin': (0.414874, 0)}.
# [WARNING 05-18 19:49:52] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 19:50:55] ax.service.ax_client: Generated new trial 19 with parameters {'min_samples': 60, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.366649, 'metric': 'euclidean'}.
# [INFO 05-18 19:51:10] ax.service.ax_client: Completed trial 19 with data: {'n_noise': (4167, 0), 'n_clusters': (18, 0), 'silhouette': (0.6731774, 0), 'calinski_harabasz': (114981.093801, 0), 'davies_bouldin': (0.464496, 0)}.
# [WARNING 05-18 19:51:10] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 19:52:14] ax.service.ax_client: Generated new trial 20 with parameters {'min_samples': 42, 'min_cluster_size': 96, 'cluster_selection_epsilon': 0.431461, 'metric': 'euclidean'}.
# [INFO 05-18 19:52:32] ax.service.ax_client: Completed trial 20 with data: {'n_noise': (2071, 0), 'n_clusters': (13, 0), 'silhouette': (0.68556446, 0), 'calinski_harabasz': (83799.088963, 0), 'davies_bouldin': (0.370086, 0)}.
# [WARNING 05-18 19:52:32] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 19:53:45] ax.service.ax_client: Generated new trial 21 with parameters {'min_samples': 42, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.374703, 'metric': 'euclidean'}.
# [INFO 05-18 19:54:02] ax.service.ax_client: Completed trial 21 with data: {'n_noise': (3559, 0), 'n_clusters': (15, 0), 'silhouette': (0.69890153, 0), 'calinski_harabasz': (91226.060432, 0), 'davies_bouldin': (0.36083, 0)}.
# [WARNING 05-18 19:54:02] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 19:55:20] ax.service.ax_client: Generated new trial 22 with parameters {'min_samples': 40, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.375559, 'metric': 'euclidean'}.
# [INFO 05-18 19:55:36] ax.service.ax_client: Completed trial 22 with data: {'n_noise': (2848, 0), 'n_clusters': (16, 0), 'silhouette': (0.7014802, 0), 'calinski_harabasz': (110691.998815, 0), 'davies_bouldin': (0.414874, 0)}.
# [WARNING 05-18 19:55:36] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 19:56:15] ax.service.ax_client: Generated new trial 23 with parameters {'min_samples': 38, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.376488, 'metric': 'euclidean'}.
# [INFO 05-18 19:56:32] ax.service.ax_client: Completed trial 23 with data: {'n_noise': (2675, 0), 'n_clusters': (16, 0), 'silhouette': (0.6967719, 0), 'calinski_harabasz': (108507.456341, 0), 'davies_bouldin': (0.419763, 0)}.
# [WARNING 05-18 19:56:32] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 19:57:32] ax.service.ax_client: Generated new trial 24 with parameters {'min_samples': 27, 'min_cluster_size': 97, 'cluster_selection_epsilon': 0.370546, 'metric': 'euclidean'}.
# [INFO 05-18 19:57:48] ax.service.ax_client: Completed trial 24 with data: {'n_noise': (1804, 0), 'n_clusters': (14, 0), 'silhouette': (0.6933553, 0), 'calinski_harabasz': (75637.128003, 0), 'davies_bouldin': (0.371378, 0)}.
# [WARNING 05-18 19:57:49] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 19:58:45] ax.service.ax_client: Generated new trial 25 with parameters {'min_samples': 37, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.372536, 'metric': 'euclidean'}.
# [INFO 05-18 19:59:02] ax.service.ax_client: Completed trial 25 with data: {'n_noise': (2951, 0), 'n_clusters': (16, 0), 'silhouette': (0.69989246, 0), 'calinski_harabasz': (110045.388799, 0), 'davies_bouldin': (0.417139, 0)}.
# [WARNING 05-18 19:59:02] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 20:00:43] ax.service.ax_client: Generated new trial 26 with parameters {'min_samples': 23, 'min_cluster_size': 63, 'cluster_selection_epsilon': 0.31391, 'metric': 'euclidean'}.
# [INFO 05-18 20:00:59] ax.service.ax_client: Completed trial 26 with data: {'n_noise': (2459, 0), 'n_clusters': (20, 0), 'silhouette': (0.66680026, 0), 'calinski_harabasz': (96336.445845, 0), 'davies_bouldin': (0.479916, 0)}.
# [WARNING 05-18 20:00:59] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 20:02:34] ax.service.ax_client: Generated new trial 27 with parameters {'min_samples': 39, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.374064, 'metric': 'euclidean'}.
# [INFO 05-18 20:02:49] ax.service.ax_client: Completed trial 27 with data: {'n_noise': (2867, 0), 'n_clusters': (16, 0), 'silhouette': (0.7002222, 0), 'calinski_harabasz': (110194.141595, 0), 'davies_bouldin': (0.415718, 0)}.
# [WARNING 05-18 20:02:49] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 20:03:48] ax.service.ax_client: Generated new trial 28 with parameters {'min_samples': 29, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.204892, 'metric': 'euclidean'}.
# [INFO 05-18 20:04:04] ax.service.ax_client: Completed trial 28 with data: {'n_noise': (4614, 0), 'n_clusters': (23, 0), 'silhouette': (0.63816637, 0), 'calinski_harabasz': (107668.144515, 0), 'davies_bouldin': (0.616328, 0)}.
# [WARNING 05-18 20:04:04] ax.models.torch.botorch_modular.utils: Using `MixedSingleTaskGP` despire the known `Yvar` values. This is a temporary measure while fixed-noise mixed BO is in the works.
# [INFO 05-18 20:05:14] ax.service.ax_client: Generated new trial 29 with parameters {'min_samples': 34, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.374993, 'metric': 'euclidean'}.
# [INFO 05-18 20:05:30] ax.service.ax_client: Completed trial 29 with data: {'n_noise': (3024, 0), 'n_clusters': (15, 0), 'silhouette': (0.68391377, 0), 'calinski_harabasz': (86177.399269, 0), 'davies_bouldin': (0.374034, 0)}.

# %%
# Retrieve the best parameters
best_param_dict = ax_client.get_pareto_optimal_parameters()

# Display the best parameters
for summary in best_param_dict:
    params, (metrics, sems) = summary
    formatted_metrics = {key: f"{value:.3f}" for key, value in metrics.items()}
    print(f"Parameters: {params}")
    print(f"Metrics: {formatted_metrics}")
    print()
# Out:
# [INFO 05-18 21:56:01] ax.modelbridge.torch: The observations are identical to the last set of observations used to fit the model. Skipping model fitting.
# [INFO 05-18 21:56:01] ax.service.utils.best_point: Using inferred objective thresholds: [ObjectiveThreshold(calinski_harabasz >= 106369.25769861166), ObjectiveThreshold(davies_bouldin <= 0.41379343189545803), ObjectiveThreshold(silhouette >= 0.701476181620725)], as objective thresholds were not specified as part of the optimization configuration on the experiment.
# Parameters: {'min_samples': 40, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.3784572732149105, 'metric': 'euclidean'}
# Metrics: {'calinski_harabasz': '106388.464', 'davies_bouldin': '0.413', 'n_clusters': '15.822', 'n_noise': '2815.580', 'silhouette': '0.701'}
#
# Parameters: {'min_samples': 40, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.37555919126415493, 'metric': 'euclidean'}
# Metrics: {'calinski_harabasz': '106580.529', 'davies_bouldin': '0.414', 'n_clusters': '15.926', 'n_noise': '2879.327', 'silhouette': '0.701'}

# %% [markdown]
# ```python
# Parameters: {'min_samples': 40, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.3784572732149105, 'metric': 'euclidean'}
# Metrics: {'calinski_harabasz': '106388.464', 'davies_bouldin': '0.413', 'n_clusters': '15.822', 'n_noise': '2815.580', 'silhouette': '0.701'}
#
# Parameters: {'min_samples': 40, 'min_cluster_size': 100, 'cluster_selection_epsilon': 0.37555919126415493, 'metric': 'euclidean'}
# Metrics: {'calinski_harabasz': '106580.529', 'davies_bouldin': '0.414', 'n_clusters': '15.926', 'n_noise': '2879.327', 'silhouette': '0.701'}
# ```

# %%
# In this case there are two optimal sets of hyperparameters that are fairly similar
# We will just use the first one
best_params, (best_metrics, best_sems) = next(iter(best_param_dict.values()))

# Perform HDBSCAN clustering on the data with the best parameters
clusterer = hdbscan.HDBSCAN(**best_params)
clusterer.fit(reduced_data)
# Out:
# HDBSCAN(cluster_selection_epsilon=0.3784572732149105, min_cluster_size=100,
#         min_samples=40)

# %%
# Create a 2D UMAP embedding of the data
reducer_2d = umap.UMAP(random_state=0)
embedding_2d = reducer_2d.fit_transform(data)

emb_df = pd.DataFrame(embedding_2d, columns=["x", "y"])
emb_df["failureType"] = df["failureType"].values
emb_df["waferMap"] = df["waferMap"].values
emb_df["cluster"] = pd.Series(clusterer.labels_).astype("category").values
emb_df.sort_values("cluster", inplace=True)

# %%
fig = px.scatter(
    emb_df,
    x="x",
    y="y",
    color="cluster",
    color_discrete_sequence=sns.color_palette(
        "tab20", n_colors=clusterer.labels_.max() + 1
    ).as_hex(),
    width=800,
    height=600,
    template="simple_white",
    color_discrete_map={-1: "lightgray"},
)
# fig.update_traces(
#     marker=dict(
#         line=dict(
#             width=emb_df["cluster"].map(lambda x: 0 if x == -1 else 0.5).values,
#             color="white",
#         )
#     )
# )
fig.show()
